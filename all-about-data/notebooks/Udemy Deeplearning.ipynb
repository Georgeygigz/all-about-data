# %% [markdown]
# ## Deep Learning
# ### Training algorithims involves the following requiremnts
# #### Data
# #### model
# #### Objective function,
# - Estimate how correct and accurate a model is
# - divided into two
# ##### Loss Function
# - Thelower the loss function the higher the level of acc accuracy
# - L2-Norm loss(Regression)
# - Cross-Entropy(Classification)
# ##### Reward Func
# -  The higher the reward function the higher the level of acc accuracy
# #### Optimization algorithm
# -
#
# ### Types of Machine Learning
# #### Supervised
# - Provide algorthm with input and their corresponding desired outputs
# - Based on this information it learns to produce output close the one we
# - SUpervised learning subdivided into
# ##### Classification
# - Provides clasification output
# ##### Regression
# - Output will be numerical types
# #### Unsupervised
# - Feed inputs but no target outputs
# - It findt it own way
# #### Reinforcement
# - Train a model to act in any envt based on the reward it recives

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image.png](attachment:image.png)
