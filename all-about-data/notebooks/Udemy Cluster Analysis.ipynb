# %% [markdown]
# ## Cluster Analysis
# - Multivarious statistical techniques that groups observation on the basis some of their features
#
# ### Example of Cluster
# ### Diffrence between Clustering and Classification
# - Clustering is used in unsupervised Learning.
# - Clustering Group data points together based on similarities among them and diffrence from others
# - Classification is used in supervised Learning.
# - Classification is predicting output category given input data
#
# ### Math prerequisites
# - Distance between two points
# - Centroids
# ![image.png](attachment:image.png)
# ![image.png](attachment:image.png)
# #### Centroids
# - Mean postion of group of points
# - Center of mass
# - Method applied to identify clusters (K-means Clustering)
#
# #### K-means Clustering
# - Choose the numbers of clusters
# - Specify the cluster seed
# - Assign each point to a centroid
# - Adjust the centroid
#
# ### Simple example of clusturing
# ### WCSS (Within clusters sum of squres)
# - if we minimize WCSS we have reached theperfet clustering solution
#
# ### Types of clustering
# - Flat(Kmeans)
# #### Hirechical(Taxonomy of animal kingdom)
# - Types
# - Agglomerative
# - Devisive
